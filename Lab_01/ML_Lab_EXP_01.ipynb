# %% [markdown]
# BLC : https://elearn.daffodilvarsity.edu.bd/course/view.php?id=38494

# %%
print('Hello Tanzim Ahamed')
# Out:
# Hello Tanzim Ahamed

# %%
v1= int (input())
v2= int (input())
if v1 > v2:
    result = v1+v2

else:
    result = v1-v2

print(result)
# Out:
# 67
# 54
# 121

# %%
num = int (input())
sum = 0
# for i in range (num)
for i in range ( 1 , num+1):
   sum = sum + i

print(sum)
# Out:
# 10
# 55

# %%
def fact (n ):
  for i in range(1 , n ):
    n = n*i
  return n

num = int ( input( ))
result = fact ( num)
print (result)
# Out:
# 5
# 120
